# %%
import os
import sys
import glob
import h5py
import numpy as np

# %%
filename = "/lustre/storeB/project/nwp/H2O/wp3/Deep_learning_predictions/Normalization/Stats_normalization_20200901_20220531.h5"
hf = h5py.File(filename, 'r')
for key in hf:
    if "_min" in key or "_max" in key:
        var = np.array(hf[key])
        print(key, var)
        if (var < -100000) or (var > 100000):
            print("..........................", key, var)
# Out:
# COVER004_max 1.0
# COVER004_min 0.0
# COVER006_max 1.0
# COVER006_min 0.0
# DSN_T_ISBA_max 11.471214154376394
# DSN_T_ISBA_min 0.0
# FRAC_LAND_AND_SEA_WATER_max 1.0
# FRAC_LAND_AND_SEA_WATER_min 0.0
# FRAC_NATURE_max 1.0
# FRAC_NATURE_min 0.0
# FRAC_SEA_max 1.0
# FRAC_SEA_min 0.0
# FRAC_WATER_max 1.0
# FRAC_WATER_min 0.0
# HSN_VEG10_ga_max -14066061.579897298
# .......................... HSN_VEG10_ga_max -14066061.579897298
# HSN_VEG10_ga_min -348397279.79433703
# .......................... HSN_VEG10_ga_min -348397279.79433703
# HSN_VEG11_ga_max -14066235.243988318
# .......................... HSN_VEG11_ga_max -14066235.243988318
# HSN_VEG11_ga_min -348313574.9334301
# .......................... HSN_VEG11_ga_min -348313574.9334301
# HSN_VEG12_ga_max 3.3791160861227564e-08
# HSN_VEG12_ga_min -348222813.54951096
# .......................... HSN_VEG12_ga_min -348222813.54951096
# HSN_VEG1_ga_max 4.127095407848008e-08
# HSN_VEG1_ga_min -349339409.6094785
# ...
